# %%
spark.conf.set("fs.s3a.access.key", "AKIATFVPM4SOEWCN5BYF")
spark.conf.set("fs.s3a.secret.key", "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")
spark.conf.set("fs.s3a.endpoint", "s3.eu-north-1.amazonaws.com")

# %%
customers_df = spark.read \
    .option("header", "true") \
    .csv("s3://banking-data-lake-ravindra/raw/customers/")

display(customers_df)
